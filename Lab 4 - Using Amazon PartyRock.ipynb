# %% [markdown]
# To get started with Amazon PartyRock, head over to https://partyrock.aws/:
#
# ![image.png](attachment:5cd0c4b4-8347-406c-a5b3-cf44a2a68363.png)

# %% [markdown]
# Click the Get Started for free button and sign in using either your Google, Apple, or Amazon account:
#
# ![image.png](attachment:6d66dac2-b8e3-4648-bddd-8f43fb3d7ba2.png)
#
# At the moment, access to PartyRock is free and no credit card is required.

# %% [markdown]
# Once you have signed in, you need to give yourself a username.

# %% [markdown]
# # Building your own app

# %% [markdown]
# You are now ready to build your own custom GenAI app. Click the Generate app button:
#
# ![image.png](attachment:07d389c7-38bd-415a-a59c-d04f155c1184.png)

# %% [markdown]
# You will be asked to describe what you want your app to do.
#
# ![image.png](attachment:3bc1d896-c98e-4de3-892b-dd6e167d8c6b.png)
#
# For my example, I want the app to chat with my users on all things Singapore.
#
# ![image.png](attachment:e336c849-c5d5-43e5-84c7-f7901f0e24eb.png)

# %% [markdown]
# That’s it! You can now view how the application will look like:

# %% [markdown]
# ![image.png](attachment:95cad70e-6152-4484-b23a-fe111072b308.png)

# %% [markdown]
# What are some of the places I must visit when I am in Singapore?
#
# ![image.png](attachment:a2b94c97-d505-4fbd-ad1f-0063e01fdb17.png)

# %% [markdown]
# ![image.png](attachment:afde4ff9-d958-403d-9736-85455d3edb3c.png)

# %% [markdown]
# # Sharing your app

# %% [markdown]
# So far the application that you have built is private (only you can access it). If you want to share it with the public, click the Share button:
#
# ![image.png](attachment:f392ce98-2bd5-492b-b7e1-aaaa5b9049d8.png)

# %% [markdown]
# Click Public:
#
# ![image.png](attachment:bf16d787-9128-40c2-8cdd-5cac0de20760.png)
#
# Click Copy link.

# %%
https://partyrock.aws/u/weimenglee/QThg856g6/SingaKnow

# %% [markdown]
# # Asking Analytical Questions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:629b9c99-53ca-400f-b212-5d2dadee563b.png)

# %% [markdown]
# Drag and drop the insurance.csv file onto the CSV File Upload box:

# %% [markdown]
# ![image.png](attachment:55cec75a-1c7f-4748-ab6d-648f3a8be5c0.png)

# %% [markdown]
# Press Cmd-Enter and type a question:

# %% [markdown]
# ![image.png](attachment:701eb0c0-8198-4d9f-aedb-3e563466e9a0.png)

# %% [markdown]
# ![image.png](attachment:aebf0719-e565-443f-87e4-8ba4c1f0c137.png)

# %% [markdown]
# ![image.png](attachment:7d055c2a-8517-4530-b01e-b6bc93346e4f.png)

# %% [markdown]
# ![image.png](attachment:18ea9ab9-fd5d-44c5-919e-04087d8effc7.png)
